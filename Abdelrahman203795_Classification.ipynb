# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('voice.csv')#read the data
data.shape  #printing the shpae of the data
# Out:
# (3168, 21)

# %%
data.head()#printing the head of the data
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %% [markdown]
# use descripe method it calculates some statistical data like percentile, mean and std of the numerical values of the DataFrame. It analyzes both numeric and object series and also the DataFrame column sets of mixed data types.

# %%
data.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.084309     3.140168    36.568461     0.895127     0.408216
# std       0.042783     4.240529   134.928661     0.044980     0.177521
# ...

# %% [markdown]
# Check what kind of data i deal with it

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
# ...

# %% [markdown]
# check if data has any values null/nan or not

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# Check for duplicates.

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3163    False
# 3164    False
# 3165    False
# 3166    False
# 3167    False
# Length: 3168, dtype: bool

# %% [markdown]
# calculates the relationship between each column in our data set.

# %%
correlation = data.corr()
correlation
# Out:
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# sd       -0.739039  1.000000 -0.562603 -0.846931 -0.161076  0.874660
# median    0.925445 -0.562603  1.000000  0.774922  0.731849 -0.477352
# Q25       0.911416 -0.846931  0.774922  1.000000  0.477140 -0.874189
# Q75       0.740997 -0.161076  0.731849  0.477140  1.000000  0.009636
# IQR      -0.627605  0.874660 -0.477352 -0.874189  0.009636  1.000000
# skew     -0.322327  0.314597 -0.257407 -0.319475 -0.206339  0.249497
# kurt     -0.316036  0.346241 -0.243382 -0.350182 -0.148881  0.316185
# sp.ent   -0.601203  0.716620 -0.502005 -0.648126 -0.174905  0.640813
# sfm      -0.784332  0.838086 -0.661690 -0.766875 -0.378198  0.663601
# mode      0.687715 -0.529150  0.677433  0.591277  0.486857 -0.403764
# centroid  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# meanfun   0.460844 -0.466281  0.414909  0.545035  0.155091 -0.534462
# ...

# %% [markdown]
# Building a Correlation matrix
# <p>visualise correlated features<br>
# build the correlation matrix, which examines the<br>
# correlation of all features </p>

# %%
fig, ax = plt.subplots()
fig.set_size_inches(13,13)
sns.heatmap(correlation,annot=True)#to write the data value in each cell.
# Out:
# <AxesSubplot:>

# %%
def correlation_Fun(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
correlated_features = correlation_Fun(data, 0.8)
len(set(correlated_features))
# Out:
# 8

# %%
data.drop(columns=correlated_features,inplace=True)#drop columns that have correlated_features >0.8

# %%
data.shape
# Out:
# (3168, 13)

# %% [markdown]
# checking for outliers in the data

# %%
data.boxplot(column= 'meanfreq', by='label', grid=False)
# Out:
# <AxesSubplot:title={'center':'meanfreq'}, xlabel='label'>

# %%
#data.boxplot(column= 'sd', by='label', grid=False)

# %% [markdown]
# Check if males and females have equal samples

# %%
data[data['label'] == 'male'].shape[0]
# Out:
# 1584

# %%
data[data['label'] == 'female'].shape[0] #males and females have equal samples
# Out:
# 1584

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import plot_confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
from sklearn.model_selection import learning_curve

# %%
# convert srting data into numberic eg. male 1, female 0
df = data
df = df.drop(['label'],axis = 1)
X = df.values
y = data['label'].values

# only one column has object type so we encode it

encoder = LabelEncoder()
y = encoder.fit_transform(y)

# %% [markdown]
# Spliting the data into testing and training data gives a 30% of the data for the testing and 70% for training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# using the decision tree as our first model that will be used for classification

# %%
tree = DecisionTreeClassifier(max_depth=2,random_state=0)
tree.fit(X_train, y_train)
y_pred = tree.predict(X_test)

# %%
print("Accuracy on training set: {:.3f}".format(tree.score(X_train, y_train)))#printing the accuracy for the training data
print("Accuracy on test set: {:.3f}".format(tree.score(X_test, y_test)))#printing the accuracy for the testing data
# Out:
# Accuracy on training set: 0.957
# Accuracy on test set: 0.944

# %% [markdown]
# # plot A confusion matrix for summarizing the performance of a DecisionTree model.
#
# <p>442(TP):- the voices that belong to male and correctly classified<br>
# 455(TN):- the voices that not belong to males and correctly classified (saying  it belongs to females)<br>
# 44(FN):-voices that belong to males but saying it belong to females<br>
# 10(FP):-voices that not belong to to males but saying it belongs to them</p>

# %%
plot_confusion_matrix(tree, X_test, y_test)  
plt.title('Confussion Matrix')
plt.show()

# %% [markdown]
# KNeighborsClassifier (KNN)

# %%
clf = KNeighborsClassifier(n_neighbors=2, metric='euclidean')
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=2)

# %%
print("Accuracy on training set: {:.3f}".format(clf.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(clf.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.895
# Accuracy on test set: 0.751

# %% [markdown]
# # plot A confusion matrix for summarizing the performance of a KNN model.
#
# <p>379(TP):- the voices that belong to male and correctly classified<br>
# 252(TN):- the voices that not belong to males and correctly classified (saying  it belongs to females)<br>
# 247(FN):-voices that belong to males but saying it belong to females<br>
# 73(FP):-voices that not belong to to males but saying it belongs to them</p>

# %%
plot_confusion_matrix(clf, X_test, y_test)  
plt.title('Confussion Matrix')
plt.show()

# %%
model = LogisticRegression(solver='liblinear')  
model.fit(X_train,y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
print('test_accuracy: {}'.format(model.score(X_train,y_train)))#print the accuarcy by using the logistic regression model
# Out:
# test_accuracy: 0.9003157419936851

# %% [markdown]
# # plot A confusion matrix for summarizing the performance of a LogisticRegression model.
#
# <p>381(TP):- the voices that belong to male and correctly classified<br>
# 477(TN):- the voices that not belong to males and correctly classified (saying  it belongs to females)<br>
# 22(FN):-voices that belong to males but saying it belong to females<br>
# 71(FP):-voices that not belong to to males but saying it belongs to them</p>

# %%
plot_confusion_matrix(model, X_test, y_test)  
plt.title('Confussion Matrix')
plt.show()

# %%
train_sizes, train_scores, test_scores = learning_curve(
    estimator=tree, 
    X=X,
    y=y,
    cv=5,
    scoring="accuracy",
    train_sizes = [0.2,0.4,0.6,0.8,1]
)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# %%
plt.subplots(1, figsize=(10,10))
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")



plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %%
train_sizes, train_scores, test_scores = learning_curve(
    estimator=clf, 
    X=X,
    y=y,
    cv=5,
    scoring="accuracy",
    train_sizes = [0.2,0.4,0.6,0.8,1]
)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# %%
plt.subplots(1, figsize=(10,10))
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")



plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %%
train_sizes, train_scores, test_scores = learning_curve(
    estimator=model,
    X=X,
    y=y,
    cv=5,
    scoring="accuracy",
    train_sizes = [0.2,0.4,0.6,0.8,1],
    n_jobs=-1
)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# %%
plt.subplots(1, figsize=(10,10))
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")



plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()
